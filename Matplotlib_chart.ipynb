# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3],[2,4,6])
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

plt.plot([1,2,3],[2,4,6])
plt.title('Priyanka data')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %%
from matplotlib import style
style.use('ggplot')
x = [1,5,2]
y = [23,45,33]
x2 = [2,6,9]
y2 =[56,34,89]

plt.scatter(x,y, label="First", linewidth=3)
plt.plot(x2,y2, label='Second')
plt.legend(loc='best')
plt.show()
