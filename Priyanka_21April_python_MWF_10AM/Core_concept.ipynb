# %%
import random
print (randon.randrange(1,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0f2834e23630> in <cell line: 2>()
#       1 import random
# ----> 2 print (randon.randrange(1,10))
#
# NameError: name 'randon' is not defined
