# %%
a = 5 + 5j
type(a)
# Out:
# complex

# %%
type(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b152ec05ccbc> in <cell line: 1>()
# ----> 1 type(a)
#
# NameError: name 'a' is not defined

# %%
name = "Priyanka"

# %%
name
# Out:
# 'Priyanka'

# %%
name="Priyanka"

# %%
name
# Out:
# 'Priyanka'

# %%
type(name)
# Out:
# str

# %%
len(name)
# Out:
# 8

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
id(name)
# Out:
# 139909599480112

# %%
number = 5

# %%
number
# Out:
# 5

# %%
type(number)
# Out:
# int

# %%
com = 5+5d
# Out:
#   File "<ipython-input-12-effa4b70763c>", line 1
#     com = 5+5d
#             ^
# SyntaxError: invalid decimal literal

# %%
com = 5+3a
# Out:
#   File "<ipython-input-13-8a5ad0110cd2>", line 1
#     com = 5+3a
#             ^
# SyntaxError: invalid decimal literal

# %%
com = 5+3j

# %%
type(com)
# Out:
# complex

# %%
number+=1

# %%
number
# Out:
# 6

# %%
numer=+1

# %%
number
# Out:
# 6

# %%
number**2
# Out:
# 36

# %%
number//2
# Out:
# 3

# %%
number/2
# Out:
# 3.0

# %%
5%2
# Out:
# 1

# %%
5==5
# Out:
# True

# %%
5!=5
# Out:
# False

# %%
5>4
# Out:
# True

# %%
5>=3
# Out:
# True

# %%
'h' in 'hello'
# Out:
# True

# %%
'h' not in 'hello'
# Out:
# False

# %%
not 'h' in 'hello'
# Out:
# False

# %%
'h' in 'hello' and 'o' in 'hello'
# Out:
# True

# %%
'h' in 'hello' or 'o' in 'hello'
# Out:
# True

# %%
4 is 4
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-35-34048f99332a>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   4 is 4
# True

# %%
4 is not 4
# Out:
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-36-6ca7c7b4bd87>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   4 is not 4
# False

# %%
adress = '''prahlad nagar
anandnagar road satellite
Ahmedabad'''

# %%
adress
# Out:
# 'prahlad nagar\nanandnagar road satellite\nAhmedabad'

# %%
print(adress)
# Out:
# prahlad nagar
# anandnagar road satellite
# Ahmedabad

# %%
name.capitalize()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-04372ab32d18> in <cell line: 1>()
# ----> 1 name.capitalize()
#
# NameError: name 'name' is not defined

# %%
name = "priyanka"

# %%
name.capitalize()
# Out:
# 'Priyanka'

# %%
name.lower()
# Out:
# 'priyanka'

# %%
name = name.upper()

# %%
name
# Out:
# 'PRIYANKA'

# %%
name.isupper()
# Out:
# True

# %%
name.islower()
# Out:
# False

# %%
name.lower()
# Out:
# 'priyanka'

# %%
name.casefold()
# Out:
# 'priyanka'

# %%
adress
# Out:
# 'prahlad nagar\nanandnagar road satellite\nAhmedabad'

# %%
adress.title()
# Out:
# 'Prahlad Nagar\nAnandnagar Road Satellite\nAhmedabad'

# %%
adress.count('a')
# Out:
# 12

# %%
adress.count('p')
# Out:
# 1

# %%
adress.count('ad')
# Out:
# 3

# %%
adress.len()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-d2426a6848af> in <cell line: 1>()
# ----> 1 adress.len()
#
# AttributeError: 'str' object has no attribute 'len'

# %%
len(adress)
# Out:
# 49

# %%
name.center(50)
# Out:
# '                     PRIYANKA                     '

# %%
name.center(50,"*")
# Out:
# '*********************PRIYANKA*********************'

# %%
name.ljust(50)
# Out:
# 'PRIYANKA                                          '

# %%
name.rjust(50)
# Out:
# '                                          PRIYANKA'

# %%
name.startswith('p')
# Out:
# False

# %%
name.startswith('P')
# Out:
# True

# %%
name.startswith('m')
# Out:
# False

# %%
name.endswith('p')
# Out:
# False

# %%
st = "Hello word! I am learning python programing"

# %%
st[4]
# Out:
# 'o'

# %%
st[-1]
# Out:
# 'g'

# %%
a= "    he   lllo   jks  fjhsdkf sfksdksjjnvkvk"
print(a.strip())
# Out:
# he   lllo   jks  fjhsdkf sfksdksjjnvkvk
