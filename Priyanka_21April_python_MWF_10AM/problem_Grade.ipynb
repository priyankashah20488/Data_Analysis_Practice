# %%
data = {
    'name' : 'priyanka',
    'standarad' : 1,
    'marks' : [],
    'subject' : ['maths','evs','english','gujrati','hindi'],
    'total_marks' : 250,
    'total_obt_marks' : float(),
    'grade_percentage' : float()
}

for i in data['subject']:
    t=float(input(f"Enter marks {i}"))
    data['marks'].append(t)

# for i in data.subject:
#   a = data.get_keys(i)
#   input(f"enter your {a} marks:")
#   data.marks.setdefault(a)
  
# t1 = sum(data['marks'])
# p1 = data['total_marks']
# p1 = float(p1)
# p1 = 100*t1/p1

# if p1 >= 70:
#   print('grade A')

# elif p1 >=60:
#     print('grade B')

# elif p1 >=50:
#   print('grade c')
# else:
#   print('fail')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-0ba736e4b20f> in <cell line: 11>()
#      10
#      11 for i  in data['subject']:
# ---> 12     t=float(input(f"Enter marks{i}"))
#      13     data['marks'].append(t)
#      14
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
p1
# Out:
# 74.6

# %%
'25.5'.isdecimal()
# Out:
# False

# %%
'25'.isdigit()
# Out:
# True

# %%
type('25.5')
# Out:
# str

# %%
'25.5'.isnumeric()
# Out:
# False

# %%
float("25.5")
# Out:
# 25.5

# %%
float("25.5s")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-57da9bcde235> in <cell line: 1>()
# ----> 1 float("25.5s")
#
# ValueError: could not convert string to float: '25.5s'
